# %% [markdown]
# # Gênero
#
# Saídas da rede:<br>
# 0: Masculino<br>
# 1: Feminino<br>

# %% [markdown]
# ## Imports e definições iniciais

# %%
import numpy as np 
from PIL import Image
import os 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,Dropout, Flatten, Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint

model_path = 'models/'
data_dir = 'data/'
data_path = data_dir + 'train_test/'
model_name = 'gênero'
n_epochs = 50
patience = 50
input_shape = (75,75,1)
output_shape = 1
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Carregando os dados

# %%
def load_data(data_type):
    if data_type == 'train':
        data_tag = '0'
    elif data_type == 'valid':
        data_tag = '1'
    else:
        data_tag = '2'
    x = os.listdir(data_path)    
    x = [file for file in x if file.split('.')[1] == data_tag]
    y = np.array([int(file.split('_')[1]) for file in x])
    x = [data_path + x for x in x] 
    x = np.array([np.array(Image.open(file))
           for file in x])
    x = np.expand_dims(x, axis=3)
    return x,y

# %%
X_train, y_train = load_data('train')
X_val, y_val = load_data('valid')

# %% [markdown]
# ## A rede neural

# %%
model = Sequential()
        
model.add(Conv2D(8, (2, 2), input_shape=(input_shape),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(8, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(8, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten()) 
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(output_shape, activation='sigmoid'))

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

# %%
from keras.utils.vis_utils import plot_model
from IPython.display import Image as im

data= plot_model(model, show_shapes=True, show_layer_names=True)
im('model.png')

# %% [markdown]
# ## Treinamento inicial

# %%
callbacks = [
    ModelCheckpoint(
        model_path+model_name+'_{acc:.3f}-{val_acc:.3f}-{epoch:02d}.h5',
        monitor='val_acc',
        verbose=1,
        save_best_only=True),
    EarlyStopping('val_acc',patience = patience),
]

history = model.fit(
        x = X_train,y=y_train,
        epochs=n_epochs,
        validation_data=(X_val,y_val),
        callbacks=callbacks
)
# Out:
# Train on 14151 samples, validate on 6604 samples
# Epoch 1/50
# 14151/14151 [==============================] - 36s 3ms/step - loss: 0.7320 - acc: 0.5651 - val_loss: 0.6395 - val_acc: 0.6532
#
# Epoch 00001: val_acc improved from -inf to 0.65324, saving model to models/genero_0.565-0.653-01.h5
# Epoch 2/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.6114 - acc: 0.6751 - val_loss: 0.5412 - val_acc: 0.7456
#
# Epoch 00002: val_acc improved from 0.65324 to 0.74561, saving model to models/genero_0.675-0.746-02.h5
# Epoch 3/50
# 14151/14151 [==============================] - 36s 3ms/step - loss: 0.5557 - acc: 0.7222 - val_loss: 0.5229 - val_acc: 0.7576
#
# Epoch 00003: val_acc improved from 0.74561 to 0.75757, saving model to models/genero_0.722-0.758-03.h5
# Epoch 4/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.5227 - acc: 0.7470 - val_loss: 0.4706 - val_acc: 0.7901
#
# Epoch 00004: val_acc improved from 0.75757 to 0.79013, saving model to models/genero_0.747-0.790-04.h5
# Epoch 5/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.5045 - acc: 0.7587 - val_loss: 0.4583 - val_acc: 0.7969loss:
#
# Epoch 00005: val_acc improved from 0.79013 to 0.79694, saving model to models/genero_0.759-0.797-05.h5
# Epoch 6/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.4928 - acc: 0.7678 - val_loss: 0.4471 - val_acc: 0.7972
#
# Epoch 00006: val_acc improved from 0.79694 to 0.79724, saving model to models/genero_0.768-0.797-06.h5
# Epoch 7/50
# 14151/14151 [==============================] - 32s 2ms/step - loss: 0.4800 - acc: 0.7785 - val_loss: 0.4441 - val_acc: 0.7975
#
# Epoch 00007: val_acc improved from 0.79724 to 0.79755, saving model to models/genero_0.779-0.798-07.h5
# Epoch 8/50
# 14151/14151 [==============================] - 32s 2ms/step - loss: 0.4681 - acc: 0.7810 - val_loss: 0.4413 - val_acc: 0.7897
#
# Epoch 00008: val_acc did not improve from 0.79755
# Epoch 9/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.4585 - acc: 0.7969 - val_loss: 0.4214 - val_acc: 0.8053 0s - loss: 0.4590 - acc: 0.79 - ETA: 0s - loss: 0.4589 - acc: 0
#
# Epoch 00009: val_acc improved from 0.79755 to 0.80527, saving model to models/genero_0.797-0.805-09.h5
# Epoch 10/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.4555 - acc: 0.8009 - val_loss: 0.4651 - val_acc: 0.7897
#
# Epoch 00010: val_acc did not improve from 0.80527
# Epoch 11/50
# 14151/14151 [==============================] - 32s 2ms/step - loss: 0.4368 - acc: 0.8040 - val_loss: 0.4124 - val_acc: 0.8098ss: 0.4370 - acc: 0.804 - ETA
#
# Epoch 00011: val_acc improved from 0.80527 to 0.80981, saving model to models/genero_0.804-0.810-11.h5
# Epoch 12/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.4376 - acc: 0.8035 - val_loss: 0.4316 - val_acc: 0.80354
#
# Epoch 00012: val_acc did not improve from 0.80981
# Epoch 13/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.4282 - acc: 0.8077 - val_loss: 0.4281 - val_acc: 0.8042
#
# Epoch 00013: val_acc did not improve from 0.80981
# Epoch 14/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.4248 - acc: 0.8130 - val_loss: 0.4253 - val_acc: 0.81335  - ETA: 0s - loss: 0.4243 - a
#
# Epoch 00014: val_acc improved from 0.80981 to 0.81329, saving model to models/genero_0.813-0.813-14.h5
# Epoch 15/50
# 14151/14151 [==============================] - 35s 2ms/step - loss: 0.4210 - acc: 0.8133 - val_loss: 0.4062 - val_acc: 0.8038
#
# Epoch 00015: val_acc did not improve from 0.81329
# Epoch 16/50
# 14151/14151 [==============================] - 36s 3ms/step - loss: 0.4101 - acc: 0.8176 - val_loss: 0.3894 - val_acc: 0.8184: - ETA: 6s  - ETA: 4s -  - ETA: 2s - loss: 0.4107 - acc:  - ETA: 1s -
#
# Epoch 00016: val_acc improved from 0.81329 to 0.81844, saving model to models/genero_0.818-0.818-16.h5
# Epoch 17/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.4125 - acc: 0.8182 - val_loss: 0.3905 - val_acc: 0.8181
#
# Epoch 00017: val_acc did not improve from 0.81844
# Epoch 18/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.4068 - acc: 0.8211 - val_loss: 0.3955 - val_acc: 0.818469 - acc: 0.821
#
# Epoch 00018: val_acc did not improve from 0.81844
# Epoch 19/50
# 14151/14151 [==============================] - 39s 3ms/step - loss: 0.4142 - acc: 0.8189 - val_loss: 0.3943 - val_acc: 0.8162
#
# Epoch 00019: val_acc did not improve from 0.81844
# Epoch 20/50
# 14151/14151 [==============================] - 37s 3ms/step - loss: 0.3964 - acc: 0.8205 - val_loss: 0.3847 - val_acc: 0.8251
#
# Epoch 00020: val_acc improved from 0.81844 to 0.82511, saving model to models/genero_0.821-0.825-20.h5
# Epoch 21/50
# 14151/14151 [==============================] - 35s 2ms/step - loss: 0.3979 - acc: 0.8216 - val_loss: 0.3991 - val_acc: 0.8166
#
# Epoch 00021: val_acc did not improve from 0.82511
# Epoch 22/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3900 - acc: 0.8247 - val_loss: 0.4029 - val_acc: 0.8113
#
# Epoch 00022: val_acc did not improve from 0.82511
# Epoch 23/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3936 - acc: 0.8258 - val_loss: 0.3989 - val_acc: 0.8189
#
# Epoch 00023: val_acc did not improve from 0.82511
# Epoch 24/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3897 - acc: 0.8263 - val_loss: 0.3879 - val_acc: 0.8204
#
# Epoch 00024: val_acc did not improve from 0.82511
# Epoch 25/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3889 - acc: 0.8279 - val_loss: 0.3935 - val_acc: 0.8268
#
# Epoch 00025: val_acc improved from 0.82511 to 0.82677, saving model to models/genero_0.828-0.827-25.h5
# Epoch 26/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3818 - acc: 0.8279 - val_loss: 0.3900 - val_acc: 0.8219
#
# Epoch 00026: val_acc did not improve from 0.82677
# Epoch 27/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3824 - acc: 0.8279 - val_loss: 0.3989 - val_acc: 0.8151
#
# Epoch 00027: val_acc did not improve from 0.82677
# Epoch 28/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3776 - acc: 0.8335 - val_loss: 0.3837 - val_acc: 0.8215
#
# Epoch 00028: val_acc did not improve from 0.82677
# Epoch 29/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3719 - acc: 0.8329 - val_loss: 0.3933 - val_acc: 0.8221
#
# Epoch 00029: val_acc did not improve from 0.82677
# Epoch 30/50
# 14151/14151 [==============================] - 38s 3ms/step - loss: 0.3814 - acc: 0.8298 - val_loss: 0.3902 - val_acc: 0.8242
#
# Epoch 00030: val_acc did not improve from 0.82677
# Epoch 31/50
# 14151/14151 [==============================] - 39s 3ms/step - loss: 0.3710 - acc: 0.8372 - val_loss: 0.3841 - val_acc: 0.8230
#
# Epoch 00031: val_acc did not improve from 0.82677
# Epoch 32/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3706 - acc: 0.8356 - val_loss: 0.3725 - val_acc: 0.8275 loss: 0.3696 - - ETA - ETA: 0s - loss: 0.3712 - acc:
#
# Epoch 00032: val_acc improved from 0.82677 to 0.82753, saving model to models/genero_0.836-0.828-32.h5
# Epoch 33/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3666 - acc: 0.8353 - val_loss: 0.4075 - val_acc: 0.8078
#
# Epoch 00033: val_acc did not improve from 0.82753
# Epoch 34/50
# 14151/14151 [==============================] - 35s 2ms/step - loss: 0.3716 - acc: 0.8360 - val_loss: 0.3797 - val_acc: 0.8227
#
# Epoch 00034: val_acc did not improve from 0.82753
# Epoch 35/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3681 - acc: 0.8362 - val_loss: 0.3901 - val_acc: 0.8281
#
# Epoch 00035: val_acc improved from 0.82753 to 0.82813, saving model to models/genero_0.836-0.828-35.h5
# Epoch 36/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3630 - acc: 0.8381 - val_loss: 0.3984 - val_acc: 0.8077
#
# Epoch 00036: val_acc did not improve from 0.82813
# Epoch 37/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3652 - acc: 0.8356 - val_loss: 0.3873 - val_acc: 0.8257
#
# Epoch 00037: val_acc did not improve from 0.82813
# Epoch 38/50
# 14151/14151 [==============================] - 35s 2ms/step - loss: 0.3621 - acc: 0.8398 - val_loss: 0.4086 - val_acc: 0.8210
#
# Epoch 00038: val_acc did not improve from 0.82813
# Epoch 39/50
# 14151/14151 [==============================] - 37s 3ms/step - loss: 0.3616 - acc: 0.8394 - val_loss: 0.4069 - val_acc: 0.8230
#
# Epoch 00039: val_acc did not improve from 0.82813
# Epoch 40/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3544 - acc: 0.8402 - val_loss: 0.3974 - val_acc: 0.8245
#
# Epoch 00040: val_acc did not improve from 0.82813
# Epoch 41/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3576 - acc: 0.8397 - val_loss: 0.3925 - val_acc: 0.8131
#
# Epoch 00041: val_acc did not improve from 0.82813
# Epoch 42/50
# 14151/14151 [==============================] - 35s 2ms/step - loss: 0.3548 - acc: 0.8406 - val_loss: 0.4240 - val_acc: 0.8047
#
# Epoch 00042: val_acc did not improve from 0.82813
# Epoch 43/50
# 14151/14151 [==============================] - 36s 3ms/step - loss: 0.3607 - acc: 0.8406 - val_loss: 0.3902 - val_acc: 0.8318
#
# Epoch 00043: val_acc improved from 0.82813 to 0.83177, saving model to models/genero_0.841-0.832-43.h5
# Epoch 44/50
# 14151/14151 [==============================] - 37s 3ms/step - loss: 0.3538 - acc: 0.8448 - val_loss: 0.3930 - val_acc: 0.8201
#
# Epoch 00044: val_acc did not improve from 0.83177
# Epoch 45/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3477 - acc: 0.8435 - val_loss: 0.3903 - val_acc: 0.8286
#
# Epoch 00045: val_acc did not improve from 0.83177
# Epoch 46/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.3512 - acc: 0.8416 - val_loss: 0.3838 - val_acc: 0.8268
#
# Epoch 00046: val_acc did not improve from 0.83177
# Epoch 47/50
# 14151/14151 [==============================] - 35s 2ms/step - loss: 0.3528 - acc: 0.8431 - val_loss: 0.4063 - val_acc: 0.8213
#
# Epoch 00047: val_acc did not improve from 0.83177
# Epoch 48/50
# 14151/14151 [==============================] - 34s 2ms/step - loss: 0.3441 - acc: 0.8460 - val_loss: 0.3829 - val_acc: 0.8159
#
# Epoch 00048: val_acc did not improve from 0.83177
# Epoch 49/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.3488 - acc: 0.8420 - val_loss: 0.3820 - val_acc: 0.8200
#
# Epoch 00049: val_acc did not improve from 0.83177
# Epoch 50/50
# 14151/14151 [==============================] - 33s 2ms/step - loss: 0.3429 - acc: 0.8472 - val_loss: 0.4071 - val_acc: 0.8268
#
# Epoch 00050: val_acc did not improve from 0.83177

# %%
import matplotlib.pyplot as plt 

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Accuracy x época')
plt.ylabel('Accuracy')
plt.xlabel('Época')
plt.legend(['Treinamento', 'Validação'], loc='upper left')
plt.show()

# %% [markdown]
# ## Selecionando o melhor modelo

# %%
from keras.models import load_model
model = load_model('models/gênero_0.842-0.843-46.h5')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# ## Ajustando o treinamento com o dataset de validação

# %%
from keras.models import load_model
model.fit(
    x = X_val,
    y=y_val,
    epochs=1,
)
# Out:
# Epoch 1/1
# 6604/6604 [==============================] - 14s 2ms/step - loss: 0.4038 - acc: 0.8192

# %% [markdown]
# ## Testando contra o dataset de teste

# %%
X_test, y_test = load_data('test')

# %% [markdown]
# #### Juntando dados de treinamento e validação em um único dataset para comparação

# %%
X_train = np.append(X_train,X_val,axis=0)
y_train = np.append(y_train,y_val,axis=0)

del X_val, y_val

# %%
acc_train = model.evaluate(x=X_train, y=y_train, verbose=1)[1]
acc_test = model.evaluate(x=X_test, y=y_test, verbose=1)[1]
print('CNN:')
print("ACC treinamento", np.round(acc_train,3))
print("ACC teste", np.round(acc_test,3))
# Out:
# 20755/20755 [==============================] - 18s 850us/step
# 2831/2831 [==============================] - 2s 849us/step
# CNN:
# ACC treinamento 0.836
# ACC teste 0.83

# %% [markdown]
# #### Comparando com modelos dummy
#
# Estragégia dummy 1: chutar sempre a maioria <br>
# Estragégia dummy 2: chute aleatório

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([10850,  9905], dtype=int64))

# %%
from sklearn.metrics import accuracy_score

most_frequent = 0
acc_train = accuracy_score(y_train,[most_frequent] * y_train.shape[0])
acc_test = accuracy_score(y_test,[most_frequent] * y_test.shape[0])
print('Estratégia 1 (maioria):')
print("ACC treinamento", np.round(acc_train,3))
print("ACC teste", np.round(acc_test,3))
print()

acc_train = accuracy_score(y_train,[np.random.randint(0,2) for i in range(y_train.shape[0])])
acc_test = accuracy_score(y_test,[np.random.randint(0,2) for i in range(y_test.shape[0])])
print('Estratégia 1 (aleatório):')
print("ACC treinamento", np.round(acc_train,3))
print("ACC teste", np.round(acc_test,3))
# Out:
# Estratégia 1 (maioria):
# ACC treinamento 0.523
# ACC teste 0.523
#
# Estratégia 1 (aleatório):
# ACC treinamento 0.496
# ACC teste 0.512

# %% [markdown]
# ## Ajustando o treinamento com o dataset de teste

# %%
model.fit(
    x = X_test,y=y_test,
    epochs=1,
)
# Out:
# Epoch 1/1
# 2831/2831 [==============================] - 6s 2ms/step - loss: 0.3858 - acc: 0.8276A: 0s - loss: 0.3838

# %% [markdown]
# ## Salvando o modelo final

# %%
model.save(model_path + model_name + '_final.h5')
