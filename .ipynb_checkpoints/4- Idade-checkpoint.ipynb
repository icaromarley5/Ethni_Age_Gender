# %% [markdown]
# # Gênero

# %% [markdown]
# ## Imports e definições iniciais

# %%
import numpy as np 
from PIL import Image
import os 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,Dropout, Flatten, Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint

model_path = 'models/'
data_dir = 'data/'
data_path = data_dir + 'train_test/'
model_name = 'idade'
n_epochs = 200
patience = 50
input_shape = (75,75,1)
output_shape = 1

# %% [markdown]
# ## Carregando os dados

# %%
def load_data(data_type):
    if data_type == 'train':
        data_tag = '0'
    elif data_type == 'valid':
        data_tag = '1'
    else:
        data_tag = '2'
    x = os.listdir(data_path)    
    x = [file for file in x if file.split('.')[0] == data_tag]
    y = np.array([int(file.split('.')[3].split('_')[0]) for file in x])
    x = [data_path + x for x in x] 
    x = np.array([np.array(Image.open(file))
           for file in x])
    x = np.expand_dims(x, axis=3)
    return x,y

# %%
X_train, y_train = load_data('train')
X_val, y_val = load_data('valid')

# %% [markdown]
# ## A rede neural

# %%
model = Sequential()
        
model.add(Conv2D(8, (2, 2), input_shape=(input_shape),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(8, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(8, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten()) 
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(output_shape, activation='relu'))

model.compile(
    optimizer='adam',
    loss='mean_absolute_error',
)

# %%
from keras.utils.vis_utils import plot_model
from IPython.display import Image as im

data= plot_model(model, show_shapes=True, show_layer_names=True)
im('model.png')

# %% [markdown]
# ## Treinamento inicial

# %%
callbacks = [
    ModelCheckpoint(
        model_path+model_name+'_{loss:.3f}-{val_loss:.3f}-{epoch:02d}.h5',
        monitor='val_loss',
        verbose=1,
        save_best_only=True),
    EarlyStopping('val_loss',patience = patience),
]

history = model.fit(
        x = X_train,y=y_train,
        epochs=n_epochs,
        validation_data=(X_val,y_val),
        callbacks=callbacks
)
# Out:
# Train on 14151 samples, validate on 6604 samples
# Epoch 1/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 21.5034 - val_loss: 15.4428
#
# Epoch 00001: val_loss improved from inf to 15.44285, saving model to models/idade_21.503-15.443-01.h5
# Epoch 2/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 18.5425 - val_loss: 15.0895
#
# Epoch 00002: val_loss improved from 15.44285 to 15.08947, saving model to models/idade_18.542-15.089-02.h5
# Epoch 3/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 17.9593 - val_loss: 14.8537
#
# Epoch 00003: val_loss improved from 15.08947 to 14.85367, saving model to models/idade_17.959-14.854-03.h5
# Epoch 4/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 17.1516 - val_loss: 13.2108
#
# Epoch 00004: val_loss improved from 14.85367 to 13.21085, saving model to models/idade_17.152-13.211-04.h5
# Epoch 5/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 16.5230 - val_loss: 12.2347
#
# Epoch 00005: val_loss improved from 13.21085 to 12.23466, saving model to models/idade_16.523-12.235-05.h5
# Epoch 6/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 15.8918 - val_loss: 13.0343
#
# Epoch 00006: val_loss did not improve from 12.23466
# Epoch 7/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 15.6724 - val_loss: 12.7350
#
# Epoch 00007: val_loss did not improve from 12.23466
# Epoch 8/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 15.3817 - val_loss: 11.4230
#
# Epoch 00008: val_loss improved from 12.23466 to 11.42300, saving model to models/idade_15.382-11.423-08.h5
# Epoch 9/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 15.0043 - val_loss: 11.1449
#
# Epoch 00009: val_loss improved from 11.42300 to 11.14492, saving model to models/idade_15.004-11.145-09.h5
# Epoch 10/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 15.0316 - val_loss: 11.5477
#
# Epoch 00010: val_loss did not improve from 11.14492
# Epoch 11/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 14.6763 - val_loss: 11.0190
#
# Epoch 00011: val_loss improved from 11.14492 to 11.01896, saving model to models/idade_14.676-11.019-11.h5
# Epoch 12/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 14.5451 - val_loss: 11.6157
#
# Epoch 00012: val_loss did not improve from 11.01896
# Epoch 13/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 14.5231 - val_loss: 10.8770
#
# Epoch 00013: val_loss improved from 11.01896 to 10.87697, saving model to models/idade_14.523-10.877-13.h5
# Epoch 14/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 14.3311 - val_loss: 10.5804
#
# Epoch 00014: val_loss improved from 10.87697 to 10.58038, saving model to models/idade_14.331-10.580-14.h5
# Epoch 15/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 14.3376 - val_loss: 11.8030
#
# Epoch 00015: val_loss did not improve from 10.58038
# Epoch 16/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 13.9625 - val_loss: 10.5913
#
# Epoch 00016: val_loss did not improve from 10.58038
# Epoch 17/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 13.8981 - val_loss: 10.1123
#
# Epoch 00017: val_loss improved from 10.58038 to 10.11228, saving model to models/idade_13.898-10.112-17.h5
# Epoch 18/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 13.7282 - val_loss: 11.8416
#
# Epoch 00018: val_loss did not improve from 10.11228
# Epoch 19/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 13.7166 - val_loss: 11.7130
#
# Epoch 00019: val_loss did not improve from 10.11228
# Epoch 20/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 13.4007 - val_loss: 9.8643
#
# Epoch 00020: val_loss improved from 10.11228 to 9.86432, saving model to models/idade_13.401-9.864-20.h5
# Epoch 21/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 12.9311 - val_loss: 9.5316
#
# Epoch 00021: val_loss improved from 9.86432 to 9.53157, saving model to models/idade_12.931-9.532-21.h5
# Epoch 22/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 12.8693 - val_loss: 11.5843
#
# Epoch 00022: val_loss did not improve from 9.53157
# Epoch 23/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 12.7249 - val_loss: 9.7242
#
# Epoch 00023: val_loss did not improve from 9.53157
# Epoch 24/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 12.7451 - val_loss: 9.7090
#
# Epoch 00024: val_loss did not improve from 9.53157
# Epoch 25/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 12.4983 - val_loss: 10.1142
#
# Epoch 00025: val_loss did not improve from 9.53157
# Epoch 26/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 12.4148 - val_loss: 10.1659
#
# Epoch 00026: val_loss did not improve from 9.53157
# Epoch 27/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 12.4430 - val_loss: 9.4914
#
# Epoch 00027: val_loss improved from 9.53157 to 9.49142, saving model to models/idade_12.443-9.491-27.h5
# Epoch 28/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 12.1697 - val_loss: 9.6819
#
# Epoch 00028: val_loss did not improve from 9.49142
# Epoch 29/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 12.0426 - val_loss: 9.3755
#
# Epoch 00029: val_loss improved from 9.49142 to 9.37549, saving model to models/idade_12.043-9.375-29.h5
# Epoch 30/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 12.1011 - val_loss: 9.7349
#
# Epoch 00030: val_loss did not improve from 9.37549
# Epoch 31/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 11.9288 - val_loss: 9.9329
#
# Epoch 00031: val_loss did not improve from 9.37549
# Epoch 32/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 12.0426 - val_loss: 9.2790
#
# Epoch 00032: val_loss improved from 9.37549 to 9.27900, saving model to models/idade_12.043-9.279-32.h5
# Epoch 33/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 12.0019 - val_loss: 10.1764
#
# Epoch 00033: val_loss did not improve from 9.27900
# Epoch 34/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 11.8909 - val_loss: 9.3723
#
# Epoch 00034: val_loss did not improve from 9.27900
# Epoch 35/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.9982 - val_loss: 13.1124
#
# Epoch 00035: val_loss did not improve from 9.27900
# Epoch 36/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.8572 - val_loss: 9.2247
#
# Epoch 00036: val_loss improved from 9.27900 to 9.22472, saving model to models/idade_11.857-9.225-36.h5
# Epoch 37/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.6590 - val_loss: 9.1970
#
# Epoch 00037: val_loss improved from 9.22472 to 9.19702, saving model to models/idade_11.659-9.197-37.h5
# Epoch 38/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 11.7187 - val_loss: 9.9263
#
# Epoch 00038: val_loss did not improve from 9.19702
# Epoch 39/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.5352 - val_loss: 9.6079
#
# Epoch 00039: val_loss did not improve from 9.19702
# Epoch 40/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.5457 - val_loss: 9.8176
#
# Epoch 00040: val_loss did not improve from 9.19702
# Epoch 41/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.4611 - val_loss: 9.0174
#
# Epoch 00041: val_loss improved from 9.19702 to 9.01739, saving model to models/idade_11.461-9.017-41.h5
# Epoch 42/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.4519 - val_loss: 9.4006
#
# Epoch 00042: val_loss did not improve from 9.01739
# Epoch 43/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.3844 - val_loss: 9.5643
#
# Epoch 00043: val_loss did not improve from 9.01739
# Epoch 44/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.3186 - val_loss: 8.9302
#
# Epoch 00044: val_loss improved from 9.01739 to 8.93022, saving model to models/idade_11.319-8.930-44.h5
# Epoch 45/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.1744 - val_loss: 9.2390
#
# Epoch 00045: val_loss did not improve from 8.93022
# Epoch 46/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.0446 - val_loss: 8.9141
#
# Epoch 00046: val_loss improved from 8.93022 to 8.91407, saving model to models/idade_11.045-8.914-46.h5
# Epoch 47/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.2858 - val_loss: 9.0017
#
# Epoch 00047: val_loss did not improve from 8.91407
# Epoch 48/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 11.2048 - val_loss: 9.0728
#
# Epoch 00048: val_loss did not improve from 8.91407
# Epoch 49/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 11.1051 - val_loss: 9.2640
#
# Epoch 00049: val_loss did not improve from 8.91407
# Epoch 50/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 10.9902 - val_loss: 8.8517
#
# Epoch 00050: val_loss improved from 8.91407 to 8.85168, saving model to models/idade_10.990-8.852-50.h5
# Epoch 51/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 11.0029 - val_loss: 9.0758
#
# Epoch 00051: val_loss did not improve from 8.85168
# Epoch 52/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 10.9719 - val_loss: 8.9126
#
# Epoch 00052: val_loss did not improve from 8.85168
# Epoch 53/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 10.9318 - val_loss: 8.6433
#
# Epoch 00053: val_loss improved from 8.85168 to 8.64335, saving model to models/idade_10.932-8.643-53.h5
# Epoch 54/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 10.7600 - val_loss: 9.2981
#
# Epoch 00054: val_loss did not improve from 8.64335
# Epoch 55/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 10.7515 - val_loss: 9.6980
#
# Epoch 00055: val_loss did not improve from 8.64335
# Epoch 56/200
# 14151/14151 [==============================] - 35s 3ms/step - loss: 10.7419 - val_loss: 8.6810
#
# Epoch 00056: val_loss did not improve from 8.64335
# Epoch 57/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 10.7543 - val_loss: 8.8420
#
# Epoch 00057: val_loss did not improve from 8.64335
# Epoch 58/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 10.7564 - val_loss: 9.1021
#
# Epoch 00058: val_loss did not improve from 8.64335
# Epoch 59/200
# 14151/14151 [==============================] - 35s 3ms/step - loss: 10.6389 - val_loss: 8.9552
#
# Epoch 00059: val_loss did not improve from 8.64335
# Epoch 60/200
# 14151/14151 [==============================] - 35s 3ms/step - loss: 10.4289 - val_loss: 9.8209
#
# Epoch 00060: val_loss did not improve from 8.64335
# Epoch 61/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 10.5525 - val_loss: 9.1670
#
# Epoch 00061: val_loss did not improve from 8.64335
# Epoch 62/200
# 14151/14151 [==============================] - 35s 3ms/step - loss: 10.4847 - val_loss: 8.9290
#
# Epoch 00062: val_loss did not improve from 8.64335
# Epoch 63/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 10.4526 - val_loss: 8.9006
#
# Epoch 00063: val_loss did not improve from 8.64335
# Epoch 64/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 10.3669 - val_loss: 9.8158
#
# Epoch 00064: val_loss did not improve from 8.64335
# Epoch 65/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 10.3577 - val_loss: 9.1340
#
# Epoch 00065: val_loss did not improve from 8.64335
# Epoch 66/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 10.4007 - val_loss: 9.3953
#
# Epoch 00066: val_loss did not improve from 8.64335
# Epoch 67/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 10.2603 - val_loss: 9.5667
#
# Epoch 00067: val_loss did not improve from 8.64335
# Epoch 68/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 10.3144 - val_loss: 8.9568
#
# Epoch 00068: val_loss did not improve from 8.64335
# Epoch 69/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 10.3659 - val_loss: 8.7319
#
# Epoch 00069: val_loss did not improve from 8.64335
# Epoch 70/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 10.0587 - val_loss: 8.5781
#
# Epoch 00070: val_loss improved from 8.64335 to 8.57806, saving model to models/idade_10.059-8.578-70.h5
# Epoch 71/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 10.1807 - val_loss: 9.7230
#
# Epoch 00071: val_loss did not improve from 8.57806
# Epoch 72/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 10.2343 - val_loss: 8.9210
#
# Epoch 00072: val_loss did not improve from 8.57806
# Epoch 73/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 10.0901 - val_loss: 8.7816
#
# Epoch 00073: val_loss did not improve from 8.57806
# Epoch 74/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 10.0775 - val_loss: 8.9197
#
# Epoch 00074: val_loss did not improve from 8.57806
# Epoch 75/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 10.0722 - val_loss: 9.3930
#
# Epoch 00075: val_loss did not improve from 8.57806
# Epoch 76/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 10.1034 - val_loss: 9.2379
#
# Epoch 00076: val_loss did not improve from 8.57806
# Epoch 77/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.9228 - val_loss: 8.6603
#
# Epoch 00077: val_loss did not improve from 8.57806
# Epoch 78/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.9761 - val_loss: 8.8391
#
# Epoch 00078: val_loss did not improve from 8.57806
# Epoch 79/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.9449 - val_loss: 8.7643
#
# Epoch 00079: val_loss did not improve from 8.57806
# Epoch 80/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.8910 - val_loss: 8.7252
#
# Epoch 00080: val_loss did not improve from 8.57806
# Epoch 81/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.8800 - val_loss: 8.4369
#
# Epoch 00081: val_loss improved from 8.57806 to 8.43691, saving model to models/idade_9.880-8.437-81.h5
# Epoch 82/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.8185 - val_loss: 8.7748
#
# Epoch 00082: val_loss did not improve from 8.43691
# Epoch 83/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.7708 - val_loss: 9.0256
#
# Epoch 00083: val_loss did not improve from 8.43691
# Epoch 84/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.8837 - val_loss: 8.7994
#
# Epoch 00084: val_loss did not improve from 8.43691
# Epoch 85/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.8117 - val_loss: 8.5482
#
# Epoch 00085: val_loss did not improve from 8.43691
# Epoch 86/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.7416 - val_loss: 9.9005
#
# Epoch 00086: val_loss did not improve from 8.43691
# Epoch 87/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.7093 - val_loss: 8.7153
#
# Epoch 00087: val_loss did not improve from 8.43691
# Epoch 88/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.7618 - val_loss: 8.4563
#
# Epoch 00088: val_loss did not improve from 8.43691
# Epoch 89/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.7258 - val_loss: 8.7024
#
# Epoch 00089: val_loss did not improve from 8.43691
# Epoch 90/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.6864 - val_loss: 8.6052
#
# Epoch 00090: val_loss did not improve from 8.43691
# Epoch 91/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.6125 - val_loss: 8.7919
#
# Epoch 00091: val_loss did not improve from 8.43691
# Epoch 92/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.6661 - val_loss: 8.6185
#
# Epoch 00092: val_loss did not improve from 8.43691
# Epoch 93/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.5478 - val_loss: 8.5307
#
# Epoch 00093: val_loss did not improve from 8.43691
# Epoch 94/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.6854 - val_loss: 8.4546
#
# Epoch 00094: val_loss did not improve from 8.43691
# Epoch 95/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.5525 - val_loss: 8.6831
#
# Epoch 00095: val_loss did not improve from 8.43691
# Epoch 96/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.5914 - val_loss: 8.6787
#
# Epoch 00096: val_loss did not improve from 8.43691
# Epoch 97/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.5676 - val_loss: 8.6574
#
# Epoch 00097: val_loss did not improve from 8.43691
# Epoch 98/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.3955 - val_loss: 9.1566
#
# Epoch 00098: val_loss did not improve from 8.43691
# Epoch 99/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.5708 - val_loss: 8.7624
#
# Epoch 00099: val_loss did not improve from 8.43691
# Epoch 100/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.5452 - val_loss: 8.4554
#
# Epoch 00100: val_loss did not improve from 8.43691
# Epoch 101/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.3333 - val_loss: 8.4913
#
# Epoch 00101: val_loss did not improve from 8.43691
# Epoch 102/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.4077 - val_loss: 8.3791
#
# Epoch 00102: val_loss improved from 8.43691 to 8.37909, saving model to models/idade_9.408-8.379-102.h5
# Epoch 103/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.4738 - val_loss: 8.9580
#
# Epoch 00103: val_loss did not improve from 8.37909
# Epoch 104/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.3773 - val_loss: 8.4056
#
# Epoch 00104: val_loss did not improve from 8.37909
# Epoch 105/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 9.2249 - val_loss: 8.8734
#
# Epoch 00105: val_loss did not improve from 8.37909
# Epoch 106/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 9.2566 - val_loss: 8.7174
#
# Epoch 00106: val_loss did not improve from 8.37909
# Epoch 107/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 9.2048 - val_loss: 9.0322
#
# Epoch 00107: val_loss did not improve from 8.37909
# Epoch 108/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.1736 - val_loss: 8.4241
#
# Epoch 00108: val_loss did not improve from 8.37909
# Epoch 109/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 9.1012 - val_loss: 8.4210
#
# Epoch 00109: val_loss did not improve from 8.37909
# Epoch 110/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 9.1058 - val_loss: 8.3371
#
# Epoch 00110: val_loss improved from 8.37909 to 8.33707, saving model to models/idade_9.106-8.337-110.h5
# Epoch 111/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 9.1519 - val_loss: 8.3569
#
# Epoch 00111: val_loss did not improve from 8.33707
# Epoch 112/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 9.2216 - val_loss: 8.5144
#
# Epoch 00112: val_loss did not improve from 8.33707
# Epoch 113/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 9.0700 - val_loss: 9.1842
#
# Epoch 00113: val_loss did not improve from 8.33707
# Epoch 114/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 8.9128 - val_loss: 8.3543
#
# Epoch 00114: val_loss did not improve from 8.33707
# Epoch 115/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 9.0426 - val_loss: 8.9624
#
# Epoch 00115: val_loss did not improve from 8.33707
# Epoch 116/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 9.0204 - val_loss: 9.0224
#
# Epoch 00116: val_loss did not improve from 8.33707
# Epoch 117/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 9.0296 - val_loss: 8.5538
#
# Epoch 00117: val_loss did not improve from 8.33707
# Epoch 118/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 9.0212 - val_loss: 8.8626
#
# Epoch 00118: val_loss did not improve from 8.33707
# Epoch 119/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 9.0134 - val_loss: 8.3458
#
# Epoch 00119: val_loss did not improve from 8.33707
# Epoch 120/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.9951 - val_loss: 8.8745
#
# Epoch 00120: val_loss did not improve from 8.33707
# Epoch 121/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.0658 - val_loss: 8.4026
#
# Epoch 00121: val_loss did not improve from 8.33707
# Epoch 122/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.0180 - val_loss: 8.5238
#
# Epoch 00122: val_loss did not improve from 8.33707
# Epoch 123/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.9146 - val_loss: 8.5310
#
# Epoch 00123: val_loss did not improve from 8.33707
# Epoch 124/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.9954 - val_loss: 8.3614
#
# Epoch 00124: val_loss did not improve from 8.33707
# Epoch 125/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.9070 - val_loss: 8.6114
#
# Epoch 00125: val_loss did not improve from 8.33707
# Epoch 126/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.9898 - val_loss: 8.4519
#
# Epoch 00126: val_loss did not improve from 8.33707
# Epoch 127/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 9.0125 - val_loss: 8.4443
#
# Epoch 00127: val_loss did not improve from 8.33707
# Epoch 128/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 9.0634 - val_loss: 8.7046
#
# Epoch 00128: val_loss did not improve from 8.33707
# Epoch 129/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.9434 - val_loss: 8.5616
#
# Epoch 00129: val_loss did not improve from 8.33707
# Epoch 130/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 8.8704 - val_loss: 8.9267
#
# Epoch 00130: val_loss did not improve from 8.33707
# Epoch 131/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 8.9747 - val_loss: 8.3950
#
# Epoch 00131: val_loss did not improve from 8.33707
# Epoch 132/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.9324 - val_loss: 8.5045
#
# Epoch 00132: val_loss did not improve from 8.33707
# Epoch 133/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.9112 - val_loss: 8.5935
#
# Epoch 00133: val_loss did not improve from 8.33707
# Epoch 134/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.9306 - val_loss: 8.6496
#
# Epoch 00134: val_loss did not improve from 8.33707
# Epoch 135/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.8396 - val_loss: 9.2590
#
# Epoch 00135: val_loss did not improve from 8.33707
# Epoch 136/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.8724 - val_loss: 8.5112
#
# Epoch 00136: val_loss did not improve from 8.33707
# Epoch 137/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.8590 - val_loss: 8.6369
#
# Epoch 00137: val_loss did not improve from 8.33707
# Epoch 138/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.9692 - val_loss: 8.4645
#
# Epoch 00138: val_loss did not improve from 8.33707
# Epoch 139/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 8.8953 - val_loss: 9.3391
#
# Epoch 00139: val_loss did not improve from 8.33707
# Epoch 140/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.8692 - val_loss: 8.8504
#
# Epoch 00140: val_loss did not improve from 8.33707
# Epoch 141/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.9304 - val_loss: 8.6569
#
# Epoch 00141: val_loss did not improve from 8.33707
# Epoch 142/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 8.8233 - val_loss: 8.3728
#
# Epoch 00142: val_loss did not improve from 8.33707
# Epoch 143/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 8.7878 - val_loss: 8.5870
#
# Epoch 00143: val_loss did not improve from 8.33707
# Epoch 144/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 8.8424 - val_loss: 8.5631
#
# Epoch 00144: val_loss did not improve from 8.33707
# Epoch 145/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 8.8376 - val_loss: 8.3274
#
# Epoch 00145: val_loss improved from 8.33707 to 8.32744, saving model to models/idade_8.838-8.327-145.h5
# Epoch 146/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 8.8621 - val_loss: 8.6100
#
# Epoch 00146: val_loss did not improve from 8.32744
# Epoch 147/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.8876 - val_loss: 8.3672
#
# Epoch 00147: val_loss did not improve from 8.32744
# Epoch 148/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.8046 - val_loss: 9.0961
#
# Epoch 00148: val_loss did not improve from 8.32744
# Epoch 149/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 8.7551 - val_loss: 8.6057
#
# Epoch 00149: val_loss did not improve from 8.32744
# Epoch 150/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 8.8223 - val_loss: 8.7914
#
# Epoch 00150: val_loss did not improve from 8.32744
# Epoch 151/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 8.9643 - val_loss: 8.4020
#
# Epoch 00151: val_loss did not improve from 8.32744
# Epoch 152/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 8.8098 - val_loss: 8.3474
#
# Epoch 00152: val_loss did not improve from 8.32744
# Epoch 153/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.6612 - val_loss: 8.7025
#
# Epoch 00153: val_loss did not improve from 8.32744
# Epoch 154/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7772 - val_loss: 8.2691
#
# Epoch 00154: val_loss improved from 8.32744 to 8.26912, saving model to models/idade_8.777-8.269-154.h5
# Epoch 155/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7429 - val_loss: 8.4896
#
# Epoch 00155: val_loss did not improve from 8.26912
# Epoch 156/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.8911 - val_loss: 8.5970
#
# Epoch 00156: val_loss did not improve from 8.26912
# Epoch 157/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7767 - val_loss: 8.3966
#
# Epoch 00157: val_loss did not improve from 8.26912
# Epoch 158/200
# 14151/14151 [==============================] - 31s 2ms/step - loss: 8.7812 - val_loss: 8.4881
#
# Epoch 00158: val_loss did not improve from 8.26912
# Epoch 159/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.8046 - val_loss: 8.4530
#
# Epoch 00159: val_loss did not improve from 8.26912
# Epoch 160/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7525 - val_loss: 8.3441
#
# Epoch 00160: val_loss did not improve from 8.26912
# Epoch 161/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6808 - val_loss: 8.3912
#
# Epoch 00161: val_loss did not improve from 8.26912
# Epoch 162/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6618 - val_loss: 8.2965
#
# Epoch 00162: val_loss did not improve from 8.26912
# Epoch 163/200
# 14151/14151 [==============================] - 31s 2ms/step - loss: 8.7714 - val_loss: 8.3482
#
# Epoch 00163: val_loss did not improve from 8.26912
# Epoch 164/200
# 14151/14151 [==============================] - 31s 2ms/step - loss: 8.7091 - val_loss: 8.5057
#
# Epoch 00164: val_loss did not improve from 8.26912
# Epoch 165/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7180 - val_loss: 8.7823
#
# Epoch 00165: val_loss did not improve from 8.26912
# Epoch 166/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7481 - val_loss: 8.4438
#
# Epoch 00166: val_loss did not improve from 8.26912
# Epoch 167/200
# 14151/14151 [==============================] - 31s 2ms/step - loss: 8.8476 - val_loss: 8.4953
#
# Epoch 00167: val_loss did not improve from 8.26912
# Epoch 168/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7715 - val_loss: 8.4385
#
# Epoch 00168: val_loss did not improve from 8.26912
# Epoch 169/200
# 14151/14151 [==============================] - 31s 2ms/step - loss: 8.8231 - val_loss: 8.3287
#
# Epoch 00169: val_loss did not improve from 8.26912
# Epoch 170/200
# 14151/14151 [==============================] - 31s 2ms/step - loss: 8.7368 - val_loss: 8.3887
#
# Epoch 00170: val_loss did not improve from 8.26912
# Epoch 171/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.8201 - val_loss: 8.3160
#
# Epoch 00171: val_loss did not improve from 8.26912
# Epoch 172/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6686 - val_loss: 8.3855
#
# Epoch 00172: val_loss did not improve from 8.26912
# Epoch 173/200
# 14151/14151 [==============================] - 31s 2ms/step - loss: 8.7500 - val_loss: 8.6162
#
# Epoch 00173: val_loss did not improve from 8.26912
# Epoch 174/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6824 - val_loss: 8.6063
#
# Epoch 00174: val_loss did not improve from 8.26912
# Epoch 175/200
# 14151/14151 [==============================] - 31s 2ms/step - loss: 8.7037 - val_loss: 8.4996
#
# Epoch 00175: val_loss did not improve from 8.26912
# Epoch 176/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7165 - val_loss: 8.5783
#
# Epoch 00176: val_loss did not improve from 8.26912
# Epoch 177/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7995 - val_loss: 8.5307
#
# Epoch 00177: val_loss did not improve from 8.26912
# Epoch 178/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.6791 - val_loss: 8.6314
#
# Epoch 00178: val_loss did not improve from 8.26912
# Epoch 179/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 8.6451 - val_loss: 8.3573
#
# Epoch 00179: val_loss did not improve from 8.26912
# Epoch 180/200
# 14151/14151 [==============================] - 36s 3ms/step - loss: 8.7181 - val_loss: 8.3240
#
# Epoch 00180: val_loss did not improve from 8.26912
# Epoch 181/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.7679 - val_loss: 8.6156
#
# Epoch 00181: val_loss did not improve from 8.26912
# Epoch 182/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.7351 - val_loss: 8.3843
#
# Epoch 00182: val_loss did not improve from 8.26912
# Epoch 183/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.6910 - val_loss: 8.4194
#
# Epoch 00183: val_loss did not improve from 8.26912
# Epoch 184/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.7520 - val_loss: 8.5252
#
# Epoch 00184: val_loss did not improve from 8.26912
# Epoch 185/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.7284 - val_loss: 8.4425
#
# Epoch 00185: val_loss did not improve from 8.26912
# Epoch 186/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6928 - val_loss: 8.4231
#
# Epoch 00186: val_loss did not improve from 8.26912
# Epoch 187/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6940 - val_loss: 8.3463
#
# Epoch 00187: val_loss did not improve from 8.26912
# Epoch 188/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7061 - val_loss: 8.6879
#
# Epoch 00188: val_loss did not improve from 8.26912
# Epoch 189/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6933 - val_loss: 8.4244
#
# Epoch 00189: val_loss did not improve from 8.26912
# Epoch 190/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6543 - val_loss: 8.4365
#
# Epoch 00190: val_loss did not improve from 8.26912
# Epoch 191/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6778 - val_loss: 8.4390
#
# Epoch 00191: val_loss did not improve from 8.26912
# Epoch 192/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.6386 - val_loss: 8.5403
#
# Epoch 00192: val_loss did not improve from 8.26912
# Epoch 193/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.6747 - val_loss: 8.5941
#
# Epoch 00193: val_loss did not improve from 8.26912
# Epoch 194/200
# 14151/14151 [==============================] - 37s 3ms/step - loss: 8.7117 - val_loss: 8.3785
#
# Epoch 00194: val_loss did not improve from 8.26912
# Epoch 195/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.7311 - val_loss: 8.5152
#
# Epoch 00195: val_loss did not improve from 8.26912
# Epoch 196/200
# 14151/14151 [==============================] - 34s 2ms/step - loss: 8.7816 - val_loss: 8.8747
#
# Epoch 00196: val_loss did not improve from 8.26912
# Epoch 197/200
# 14151/14151 [==============================] - 35s 2ms/step - loss: 8.7685 - val_loss: 8.3804
#
# Epoch 00197: val_loss did not improve from 8.26912
# Epoch 198/200
# 14151/14151 [==============================] - 33s 2ms/step - loss: 8.7081 - val_loss: 8.4362
#
# Epoch 00198: val_loss did not improve from 8.26912
# Epoch 199/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7039 - val_loss: 8.4018
#
# Epoch 00199: val_loss did not improve from 8.26912
# Epoch 200/200
# 14151/14151 [==============================] - 32s 2ms/step - loss: 8.7360 - val_loss: 8.7833
#
# Epoch 00200: val_loss did not improve from 8.26912

# %%
import matplotlib.pyplot as plt 

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Accuracy x época')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Época')
plt.legend(['Treinamento', 'Validação'], loc='upper left')
plt.show()

# %% [markdown]
# ## Selecionando o melhor modelo

# %%
from keras.models import load_model
model = load_model('models/idade_8.838-8.327-145.h5')

# %% [markdown]
# ## Ajustando o treinamento com o dataset de validação

# %%
from keras.models import load_model
model.fit(
    x = X_val,
    y=y_val,
    epochs=1,
)
# Out:
# Epoch 1/1
# 6604/6604 [==============================] - 14s 2ms/step - loss: 9.5492

# %% [markdown]
# ## Testando contra o dataset de teste

# %%
X_test, y_test = load_data('test')

# %% [markdown]
# #### Juntando dados de treinamento e validação em um único dataset para comparação

# %%
X_train = np.append(X_train,X_val,axis=0)
y_train = np.append(y_train,y_val,axis=0)

del X_val, y_val

# %%
loss_train = model.evaluate(x=X_train, y=y_train, verbose=1)
loss_test = model.evaluate(x=X_test, y=y_test, verbose=1)
print('CNN:')
print("MAE treinamento", np.round(loss_train,3))
print("MAE teste", np.round(loss_test,3))
# Out:
# 20755/20755 [==============================] - 18s 879us/step
# 2831/2831 [==============================] - 3s 935us/step
# CNN:
# MAE treinamento 7.891
# MAE teste 8.524

# %% [markdown]
# #### Comparando com modelos dummy
#
# Estragégia dummy 1: chutar a média dos valores <br>
# Estragégia dummy 2: chute aleatório

# %%
np.mean(y_train),np.max(y_train),np.min(y_train)
# Out:
# (33.32262105516743, 116, 1)

# %%
from sklearn.metrics import mean_absolute_error

mean = 33
loss_train = mean_absolute_error(y_train,[mean] * y_train.shape[0])
loss_test = mean_absolute_error(y_test,[mean] * y_test.shape[0])
print('Estratégia 1 (maioria):')
print("MAE treinamento", np.round(loss_train,3))
print("MAE teste", np.round(loss_test,3))
print()

y_max = 116
y_min = 1
loss_train = mean_absolute_error(y_train,[np.random.randint(y_min,y_max+1) for i in range(y_train.shape[0])])
loss_test = mean_absolute_error(y_test,[np.random.randint(y_min,y_max+1) for i in range(y_test.shape[0])])
print('Estratégia 1 (aleatório):')
print("MAE treinamento", np.round(loss_train,3))
print("MAE teste", np.round(loss_test,3))
# Out:
# Estratégia 1 (maioria):
# MAE treinamento 15.319
# MAE teste 15.156
#
# Estratégia 1 (aleatório):
# MAE treinamento 37.992
# MAE teste 38.004

# %% [markdown]
# ## Ajustando o treinamento com o dataset de teste

# %%
model.fit(
    x = X_test,y=y_test,
    epochs=1,
)
# Out:
# Epoch 1/1
# 2831/2831 [==============================] - 6s 2ms/step - loss: 9.4346

# %% [markdown]
# ## Salvando o modelo final

# %%
model.save(model_path + model_name + '_final.h5')
